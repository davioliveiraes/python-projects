# %% [markdown]
# # Estruturas de repetição
#
# <span style="color: red;"><b>Todos os exercícios são feitos partindo-se do pressuposto de que todas as entradas são dadas de forma correta. Casos limite não mencionados no enunciado não são abordados porque não fazem parte do exercício.</b></span>

# %% [markdown]
# #### 1. Faça um programa que peça uma nota, entre zero e dez. Mostre uma mensagem caso o valor seja inválido e continue pedindo até que o usuário informe um valor válido.

# %%
nota = float(input("Digite uma nota de 0 a 10: "))

while not (0 <= nota <= 10):
    print("Nota inválida, tente novamente!")
    nota = float(input("Digite uma nota de 0 10: "))

print(f"NOTA REGISTRADA COM SUCESSO - NOTA: {nota}")
# Out:
# Nota inválida, tente novamente!
# NOTA REGISTRADA COM SUCESSO - NOTA: 9.0

# %% [markdown]
# #### 2. Faça um programa que leia um nome de usuário e a sua senha e não aceite a senha igual ao nome do usuário, mostrando uma mensagem de erro e voltando a pedir as informações.

# %%
email = str(input("Digite o seu email de login: "))
senha = str(input("Digite a sua senha de login: "))

while not email != senha:
    print("Opa, a senha não pode ser a mesma do email de login, por favor tente novamente...")
    email = str(input("Digite o seu email de login: "))
    senha = str(input("Digite a sua senha de login: "))

print("LOGIN REALIZADA COM SUCESSO!")
# Out:
# Opa, a senha não pode ser a mesma do email de login, por favor tente novamente...
# Opa, a senha não pode ser a mesma do email de login, por favor tente novamente...
# LOGIN REALIZADA COM SUCESSO!

# %% [markdown]
# #### 3. Faça um programa que leia e valide as seguintes informações (e para cada uma delas, continue pedindo a informação até o usuário inserir corretamente):
# ##### Nome: maior que 3 caracteres;
# ##### Idade: entre 0 e 150;
# ##### Salário: maior que zero;
# ##### Sexo: 'f' ou 'm';
# ##### Estado Civil: 's', 'c', 'v', 'd';

# %%
nome = str(input("Digite o seu nome: "))
while not len(nome) > 3:
    print("Nome inválido, por favor inserir um nome com mais de 3 letras.")
    nome = str(input("Digite o seu nome: "))

print("NOME CADASTRADO COM SUCESSO.")

idade = int(input("Digite a sua idade: "))
while not 0 < idade < 150:
    print("Idade inválida, por favor inserir uma idade entre 0 e 150.")
    idade = int(input("Digite a sua idade: "))

print("IDADE CADASTRADA COM SUCESSO.")

salario = float(input("Digite o seu salário: R$"))

while not salario > 0:
    print("Salário inválido, por favor inserir um salário maior que zero.")
    salario = float(input("Digite o seu salário: R$"))

print("SALÁRIO CADASTRADO COM SUCESSO")

sexo = str(input("Digite o seu sexo[M/F]: ")).upper()

while not sexo in ['M', 'F']:
    print("Sexo inválido, por favor inserir um sexo M - masculino ou F - Feminino.")
    sexo = str(input("Digite o seu sexo[M/F]: ")).upper()

print("SEXO CADASTRADO COM SUCESSO.")

estado_civil = str(input("Digite o seu estado civil: ")).upper()

while not estado_civil in ['S', 'C', 'V', 'D']:
    print("Estado civil inválido, por favor inserir um estado civil: s - solteiro; c - casado; v - viúvo; D - divorciado")
    estado_civil = str(input("Digite o seu estado civil: ")).upper

print("ESTADO CIVIL CADASTRADO COM SUCESSO.")

print("==" * 30)
print("                      FICHA COLABORADOR                ")
print("==" * 30)

print(f"NOME: {nome}")
print(f"IDADE: {idade}")
print(f"SALÁRIO: R${salario:,.2f}")
print(f"SEXO: {sexo}")
print(f"ESTADO CIVIL: {estado_civil}")
# Out:
# NOME CADASTRADO COM SUCESSO.
# IDADE CADASTRADA COM SUCESSO.
# SALÁRIO CADASTRADO COM SUCESSO
# SEXO CADASTRADO COM SUCESSO.
# ESTADO CIVIL CADASTRADO COM SUCESSO.
# ...
#                       FICHA COLABORADOR
# ...
# NOME: Davi
# IDADE: 24
# SALÁRIO: R$2,500.00
# SEXO: M
# ESTADO CIVIL: C

# %% [markdown]
# #### 4. Supondo que a população de um país A seja da ordem de 80000 habitantes com uma taxa anual de crescimento de 3% e que a população de B seja 200000 habitantes com uma taxa de crescimento de 1.5%. Faça um programa que calcule e escreva o número de anos necessários para que a população do país A ultrapasse ou iguale a população do país B, mantidas as taxas de crescimento.

# %%
# Fórmula para o crescimento anual:
# novo_valor = valor_original * (1 + taxa de crescimento)

populacao_A = 80000
populacao_B = 200000

tempo = 0

while populacao_A < populacao_B:
    populacao_A *= 1.03 
    populacao_B *= 1.015
    tempo += 1

print(f"O tempo necessário para que a população do país A ultrapasse ou iguale a população do país B são de: {tempo} anos.")

habitantes_a = 80000
habitantes_b = 200000

anos = 0

while habitantes_a < habitantes_b:
    habitantes_a = habitantes_a * (1 + 0.03)
    habitantes_b = habitantes_b * (1 + 0.015)
    anos += 1
print(f"A quantidade de anos que vai levar para população b ultrapassar ou igualar a população a é de: {anos} anos")
# Out:
# O tempo necessário para que a população do país A ultrapasse ou iguale a população do país B são de: 63 anos.
# A quantidade de anos que vai levar para população b ultrapassar ou iguale a população a é de: 63 anos

# %% [markdown]
# #### 5. Altere o programa anterior permitindo ao usuário informar as populações e as taxas de crescimento iniciais. Valide a entrada e permita repetir a operação.

# %%
repete = ''

while repete in 'Ss':
    
    populacao_a = int(input("Digite a quantidade da população do país A: "))
    populacao_b = int(input("Digite a quantidade da população do país B: "))

    while populacao_a <= 0 or populacao_b <= 0:
        print("As populações precisam ser maiores do que zero.")
        populacao_a = int(input("Digite a quantidade da população do país A: "))
        populacao_b = int(input("Digite a quantidade da população do país B: "))
    
    taxa_cresc_a = float(input("Digite a taxa de crecimento do país A em porcentagem(Exemplo: 3 para 3%): "))
    taxa_cresc_b = float(input("Digite a taxa de crescimento do país B em porcentagem(Exemplo: 3 para 3%): "))

    while taxa_cresc_a <= 0 or taxa_cresc_b <= 0:
        print("A taxa de crescimento precisa ser maior do que zero.")
        taxa_cresc_a = float(input("Digite a taxa de crescimneto do país A em porcentagem(Exemplo: 3 para 3%): "))
        taxa_cresc_b = float(input("Digite a taxa de crescimento do país B em porcentagem(Exemplo: 3 para 3%): "))
    
    taxa_cresc_a = taxa_cresc_a / 100 + 1
    taxa_cresc_b = taxa_cresc_b / 100 + 1

    anos = 0

    while populacao_a < populacao_b:
        populacao_a = populacao_a * taxa_cresc_a
        populacao_B = populacao_b * taxa_cresc_b
        anos += 1

    print(f"A quantidade de anos para o país A superar ou igualhar o país B em população é de: {anos} anos.") 

    repete = str(input("Você deseja repetir a operação[S - Sim; N - Não]: "))
    if repete in 'Nn':
        break
# Out:
# A quantidade de anos para o país A superar ou iguale o país B em população é de: 0 anos.
# A quantidade de anos para o país A superar ou iguale o país B em população é de: 158 anos.

# %% [markdown]
# #### 6. Faça um programa que peça para o usuário inserir o faturamento dos últimos 5 meses (individualmente) e informe o maior faturamento

# %%
count = 1
maior_fatura = 0
while count <= 5:
    fatura_mes = float(input(f"Digite o faturamento do {count}° mês: R$"))
    if fatura_mes > maior_fatura:
        maior_fatura = fatura_mes
    count += 1
print(f"O maior faturamento digitado foi: R${maior_fatura:,.2f}")
# Out:
# O maior faturamento digitado foi: R$4,550.00

# %% [markdown]
# #### 7. Faça um programa que peça para o usuário inserir o faturamento dos últimos 5 meses (individualmente) e informe o faturamento total (soma) e o faturamento médio por mês (média).

# %%
count = 1
soma_fatura = 0
media_fatura = 0

while count <= 5:
    fatura_mes = float(input(f"Digite o faturamento {count}° mês: R$"))
    soma_fatura += fatura_mes
    media_fatura = soma_fatura / 5
    count += 1

print(f"A soma do faturamento dos meses é de: R${soma_fatura:,.2f}")
print(f"A média do faturamento dos meses é de: R${media_fatura:,.2f}")
# Out:
# A soma do faturamento dos meses é de: R$10,000.00
# A média do faturamento dos meses é de: R$2,000.00

# %% [markdown]
# #### 8. Faça um programa que consiga categorizar a idade das equipes de uma empresa. Faça um programa que peça para n pessoas a sua idade, ao final o programa devera verificar se a média de idade da equipe varia entre 0 e 25 (jovem) ,26 e 60 (sênior) e maior que 60 (idosa); e então, dizer se a equipe é jovem, sênior ou idosa, conforme a média calculada.

# %%
soma_idade = 0
qtda_idade = 0
media_idade = 0

while True:
    idade = int(input("Digite a sua idade: "))
    soma_idade += idade
    qtda_idade += 1

    deseja_continuar = str(input("Deseja continuar(S - Sim ou N - Não): "))
    if deseja_continuar in 'Nn':
        break

media_idade = soma_idade / qtda_idade
print(f"QUANTIDADE DE IDADES DIGITADAS: {qtda_idade}")
print(f"A SOMA DAS IDADES É: {soma_idade} anos")
print(f"MÉDIA DE IDADE DA EQUIPE É: {media_idade} anos")

if 0 < media_idade <= 25:
    print("A equipe é jovem!")
elif 26 < media_idade <= 60:
    print("A equipe é sênior!")
elif media_idade > 60:
    print("A equipe é idosa!")
# Out:
# QUANTIDADE DE IDADES DIGITADAS: 4
# A SOMA DAS IDADES É 185
# MÉDIA DE IDADE DA EQUIPE É: 46.25 anos
# A equipe é sênior!

# %% [markdown]
# #### 9. Numa eleição existem três candidatos. Faça um programa que peça o número total de eleitores. Peça para cada eleitor votar e ao final mostrar o número de votos de cada candidato.

# %%
qtda_eleitores = int(input("Digite o número total de eleitores: "))

count = 1
candidato1 = 0
candidato2 = 0
candidato3 = 0

while count <= qtda_eleitores:
    voto = int(input(f"{count}° Eleitor; - Digite 1 para o Harvey Specter; Digite 2 para o Mike Ross; Digite 3 para Luis Litt: "))
    if voto == 1:
        candidato1 += 1
    if voto == 2:
        candidato2 += 1
    if voto == 3:
        candidato3 += 1
    count += 1

print(f"Candidato 1 - Harvey Specter obteve: {candidato1} votos")
print(f"Candidato 2 - Mike Ross obteve: {candidato2} votos")
print(f"Candidato 3 - Luis Litt obteve: {candidato3} votos")
# Out:
# Candidato 1 - Harvey Specter obteve: 1 votos
# Candidato 2 - Mike Ross obteve: 3 votos
# Candidato 3 - Luis Litt obteve: 1 votos

# %% [markdown]
# #### 10. Faça um programa que calcule o valor total investido por um colecionador em sua coleção de CDs e o valor médio gasto em cada um deles. O usuário deverá informar a quantidade de CDs e o valor para em cada um.

# %%
qtda_cds = int(input("Informe a quantidade de CDs comprado: "))

count = 1
soma_valor_cds = 0
media_valor_cds = 0

while count <= qtda_cds:
    valor_cds = float(input(f"Informe o preço do {count}° CD: R$"))
    soma_valor_cds += valor_cds
    media_valor_cds = soma_valor_cds / qtda_cds
    count += 1

print(f"O valor total investido é de: R${soma_valor_cds:,.2f}")
print(f"A média de gasto em cada CD é de: R${media_valor_cds:,.2f}")
# Out:
# O valor total investido é de: R$3,500.00
# A média gasto em cada CD é de: R$1,166.67

# %% [markdown]
# #### 11. O Sr. Manoel Joaquim possui uma grande loja de artigos de R\\$ 1,99, com cerca de 10 caixas. Para agilizar o cálculo de quanto cada cliente deve pagar ele desenvolveu um tabela que contém o número de itens que o cliente comprou e ao lado o valor da conta. Desta forma a atendente do caixa precisa apenas contar quantos itens o cliente está levando e olhar na tabela de preços. Você foi contratado para desenvolver o programa que monta esta tabela de preços, que conterá os preços de 1 até 50 produtos, conforme o exemplo abaixo:
# <pre>
# Lojas Quase Dois - Tabela de preços
# 1 - R$ 1.99
# 2 - R$ 3.98
# ...
# 50 - R$ 99.50
# </pre>

# %%
print(" == LOJAS QUASE DOSI - TABELA DE PREÇOS == ")
count = 1
while count <= 50:
    print(f"{count} artigo(com 10 caixas) - R${count * 1.99:,.2f}")
    count += 1
# Out:
#  == LOJAS QUASE DOSI - TABELA DE PREÇOS ==
# 1 artigo(com 10 caixas) - R$1.99
# 2 artigo(com 10 caixas) - R$3.98
# 3 artigo(com 10 caixas) - R$5.97
# 4 artigo(com 10 caixas) - R$7.96
# 5 artigo(com 10 caixas) - R$9.95
# 6 artigo(com 10 caixas) - R$11.94
# 7 artigo(com 10 caixas) - R$13.93
# 8 artigo(com 10 caixas) - R$15.92
# 9 artigo(com 10 caixas) - R$17.91
# 10 artigo(com 10 caixas) - R$19.90
# 11 artigo(com 10 caixas) - R$21.89
# 12 artigo(com 10 caixas) - R$23.88
# 13 artigo(com 10 caixas) - R$25.87
# 14 artigo(com 10 caixas) - R$27.86
# 15 artigo(com 10 caixas) - R$29.85
# 16 artigo(com 10 caixas) - R$31.84
# 17 artigo(com 10 caixas) - R$33.83
# 18 artigo(com 10 caixas) - R$35.82
# 19 artigo(com 10 caixas) - R$37.81
# 20 artigo(com 10 caixas) - R$39.80
# 21 artigo(com 10 caixas) - R$41.79
# 22 artigo(com 10 caixas) - R$43.78
# 23 artigo(com 10 caixas) - R$45.77
# 24 artigo(com 10 caixas) - R$47.76
# 25 artigo(com 10 caixas) - R$49.75
# 26 artigo(com 10 caixas) - R$51.74
# ...

# %% [markdown]
# #### 12. Um funcionário de uma empresa recebe aumento salarial anualmente: Sabe-se que:
# <pre>
# Esse funcionário foi contratado em 1995, com salário inicial de R$ 1.000,00;
# Em 1996 recebeu aumento de 1,5% sobre seu salário inicial;
# A partir de 1997 (inclusive), os aumentos salariais sempre correspondem ao dobro do percentual do ano anterior. Faça um programa que determine o salário desse funcionário em 2003.
# </pre>

# %%
salario = 1000 * 1.015
percentual = 0.015

for i in range(1997, 2004):
    percentual *= 2
    salario *= (1 + percentual)

print(f"O seu novo salário é: R${salario:,.2f}")
# Out:
# O seu novo salário é: R$13,036.15

# %% [markdown]
# #### 13. O cardápio de uma lanchonete é o seguinte:
# <pre>
# Especificação   Código  Preço
# Cachorro Quente 100     R$ 1,20
# Bauru Simples   101     R$ 1,30
# Bauru com ovo   102     R$ 1,50
# Hambúrguer      103     R$ 1,20
# Cheeseburguer   104     R$ 1,30
# Refrigerante    105     R$ 1,00
# Faça um programa que leia o código dos itens pedidos e as quantidades desejadas. Calcule e mostre o valor a ser pago por item (preço * quantidade) e o total geral do pedido. Considere que o cliente deve informar quando o pedido deve ser encerrado.
# </pre>

# %%
total = 0

while True:

    codigo_produto = int(input("Digite o código do produto que quer pedir: "))
    qtda_produto = int(input("Digite a quantidade que quer levar desse produto: "))

    if codigo_produto == 100:
        total += 1.20 * qtda_produto
    elif codigo_produto == 101:
        total += 1.30 * qtda_produto
    elif codigo_produto == 102:
        total += 1.50 * qtda_produto
    elif codigo_produto == 103:
        total += 1.20 * qtda_produto
    elif codigo_produto == 104:
        total += 1.30 * qtda_produto
    elif codigo_produto == 105:
        total += 1.00 * qtda_produto
    else:
        print("Código inválido!")

    deseja_encerrar = str(input("Deseja Encerrar[S/N]: "))

    if deseja_encerrar in 'Ss':
        break

print(f"O total a pagar é: R${total:,.2f}")
# Out:
# Código inválido!
# O total a pagar é: R$2.00

# %% [markdown]
# #### 14. Uma grande emissora de televisão quer fazer uma enquete entre os seus telespectadores para saber qual o melhor jogador após cada jogo. Para isto, faz-se necessário o desenvolvimento de um programa, que será utilizado pelas telefonistas, para a computação dos votos. Sua equipe foi contratada para desenvolver este programa, utilizando a linguagem de programação Python. Para computar cada voto, a telefonista digitará um número, entre 1 e 23, correspondente ao número da camisa do jogador. Um número de jogador igual zero, indica que a votação foi encerrada. Se um número inválido for digitado, o programa deve ignorá-lo, mostrando uma breve mensagem de aviso, e voltando a pedir outro número. Após o final da votação, o programa deverá exibir:
# <pre>a. O total de votos computados;
# b. Os números e respectivos votos de todos os jogadores que receberam votos;
# c. O percentual de votos de cada um destes jogadores;
# d. O número do jogador escolhido como o melhor jogador da partida, juntamente com o número de votos e o percentual de votos dados a ele.
#         Observe que os votos inválidos e o zero final não devem ser computados como votos. O resultado aparece ordenado pelo número do jogador. O programa deve fazer uso de arrays. O programa deverá executar o cálculo do percentual de cada jogador através de uma função. Esta função receberá dois parâmetros: o número de votos de um jogador e o total de votos. A função calculará o percentual e retornará o valor calculado. Abaixo segue uma tela de exemplo. O disposição das informações deve ser o mais próxima possível ao exemplo. Os dados são fictícios e podem mudar a cada execução do programa. Ao final, o programa deve ainda gravar os dados referentes ao resultado da votação em um arquivo texto no disco, obedecendo a mesma disposição apresentada na tela.</pre>
# ```
# Enquete: Quem foi o melhor jogador?
#
# Número do jogador (0=fim): 9
# Número do jogador (0=fim): 10
# Número do jogador (0=fim): 9
# Número do jogador (0=fim): 10
# Número do jogador (0=fim): 11
# Número do jogador (0=fim): 10
# Número do jogador (0=fim): 50
# Informe um valor entre 1 e 23 ou 0 para sair!
# Número do jogador (0=fim): 9
# Número do jogador (0=fim): 9
# Número do jogador (0=fim): 0
#
# Resultado da votação:
#
# Foram computados 8 votos.
#
# Jogador Votos           %
# 9               4               50,0%
# 10              3               37,5%
# 11              1               12,5%
# ```

# %%
votos = []
print("(Enquete) == Quem foi o melhor jogador da partida == ")
for i in range(23):
    votos.append(0)

while True:
    numero = int(input("Digite o número do jogador: "))
    if not 1 <= numero <= 23:
        print("Por favor inserir um número de 1 a 23!")
    
    deseja_sair = str(input("Desejar sair[S/N]: "))
    if deseja_sair in 'Ss':
        break
    votos[numero - 1] += 1

total = sum(votos)
print(f"Foram computados: {total} votos.")
print("JOGADOR\tVOTOS\t%")
for i, voto in enumerate(votos):
    if voto > 0:
        print(f"{i+1}\t{voto}\t{voto/total:.1%}")

melhor = max(votos)
i = votos.index(melhor)
percentagem = melhor/total
print(f"O melhor jogador foi o do número {i+1}, com {melhor} votos, correspondente a {percentagem:.0%} do total de votos.")
# Out:
# (Enquete) == Quem foi o melhor jogador da partida ==
# Foram computados: 6 votos.
# JOGADOR	VOTOS	%
# 3	2	33.3%
# 7	1	16.7%
# 10	2	33.3%
# 20	1	16.7%
# O melhor jogador foi o do número 3, com 2, correspondente a 33% do total de votos.
